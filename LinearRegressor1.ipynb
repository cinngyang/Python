# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot  as plt
import seaborn as sns
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dataset = pd.read_csv('C:/Data/GitHub/Python/SampleFile/SideView.csv')
pd.DataFrame(dataset)
dataset.groupby('WDD').size()
# Out:
# WDD
# 452.5-450    606
# dtype: int64

# %%
dataset=dataset[['WT', 'SPC_VALUE', 'SPC_RANGE', 'PRE_CIE_X_AVG', 'PRE_CIE_Y_AVG','CIE_X_AVG', 'CIE_Y_AVG']]
dataset=dataset.dropna(axis='rows')
dataset.shape
# Out:
# (554, 7)

# %%
Datacor=dataset.corr()
plt.subplots(figsize=(7, 7))
sns.heatmap(Datacor, annot=True, vmax=1, square=True, cmap="Blues")

# %%
X=dataset[['WT']]
y=dataset[['CIE_X_AVG']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred = regressor.predict(X_test)

# %%
# Visualising the Training set results
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('WT vs CIE_X_AVG (Training set)')
plt.xlabel('WT')
plt.ylabel('CIE_X_AVG')
plt.show()

# %%
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('WT vs CIE_X_AVG (Text set)')
plt.xlabel('WT')
plt.ylabel('CIE_X_AVG')
plt.show()
