# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/cinngyang/Python/blob/master/matplotlib.ipynb)

# %% [markdown]
# [Seaborn 資料視覺化](https://ithelp.ithome.com.tw/articles/10186624)<br>
# [graph-gallery](https://python-graph-gallery.com/45-control-color-of-each-marker-seaborn/)<br>[Subplot](https://morvanzhou.github.io/tutorials/data-manipulation/plt/4-1-subpot1/)<br>

# %% [markdown]
# >[Import Data - 整理 iris](#scrollTo=Ajyrp6p2Vkji)
#
# >[Create Data Frame](#scrollTo=8bfPVi5FVjQO)
#
# >[畫圖](#scrollTo=CiwdI1y5WmAi)

# %% [markdown]
# # Import Data - 整理 iris

# %%
from google.colab import files
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from scipy import stats

# %%
from sklearn.datasets import load_iris
org_irs=load_iris()

# %%
print(org_irs.DESCR)
# Out:
# Iris Plants Database
# ...
#
# Notes
# -----
# Data Set Characteristics:
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20  0.76     0.9565  (high!)
# ...

# %%
print(type(org_irs.data))
print(org_irs.data.shape)
print(type(org_irs.feature_names))
print(org_irs.feature_names)
print(type(org_irs.target))
print(len(org_irs.target))
print(type(org_irs.target_names))
print(len(org_irs.target_names))
# Out:
# <class 'numpy.ndarray'>
# (150, 4)
# <class 'list'>
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# <class 'numpy.ndarray'>
# 150
# <class 'numpy.ndarray'>
# 3

# %% [markdown]
# # Create Data Frame

# %%
#Create DataFrame
iris=pd.DataFrame(data=org_irs.data,columns=org_irs.feature_names)
# add coloum
iris['target']=org_irs.target
iris['target_names']=org_irs.target
print(org_irs.target_names)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %% [markdown]
# Data Frame map dict

# %%
#Map Dict
my_dict = {0:'setosa', 1:'versicolor', 2:'virginica'}
iris['target_names'] = iris['target_names'].map(my_dict)

# %%
print(iris.info())
iris.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# sepal length (cm)    150 non-null float64
# sepal width (cm)     150 non-null float64
# petal length (cm)    150 non-null float64
# petal width (cm)     150 non-null float64
# target               150 non-null int64
# target_names         150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.1+ KB
# None
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
#
#    target target_names
# 0       0       setosa
# 1       0       setosa

# %%
col=iris.columns[0:4]
print(col)
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %% [markdown]
# # 畫圖

# %%
fig = plt.figure()
fig.add_subplot()
sns.pairplot(data=iris[col])
plt.savefig('X.jpeg')
files.download('X.jpeg')

# %%
# Out:
# Object `matplotlib.add_subplot` not found.

# %%
fig = plt.figure()
fig.add_subplot(121)
sns.regplot(x="sepal length (cm)", y="sepal width (cm)",fit_reg=False,data=iris ,label='target_name')
fig.add_subplot(122)
sns.regplot(x="sepal length (cm)", y="petal length (cm)",fit_reg=False,data=iris ,label='target_name')
sns.pairplot(data=iris[col])
fig.show()
fig.savefig('Z.jpeg')
files.download('Z.jpeg')
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
sns.regplot(x="sepal length (cm)", y="sepal width (cm)",fit_reg=False,data=iris ,label='target_name')

# %%
? sns.regplot()
