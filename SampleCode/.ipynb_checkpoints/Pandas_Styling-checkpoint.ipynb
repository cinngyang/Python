# %% [markdown]
# <a href="https://colab.research.google.com/github/cinngyang/Python/blob/master/SampleCode/Pandas_Styling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas 格式
# [pandas-docs](http://pandas.pydata.org/pandas-docs/version/0.23/style.html)
# + df.style.applymap
# + apply 函數
# + Styler.applymap(func) for elementwise styles
# + Styler.apply(func, axis=0) for columnwise styles
# + Styler.apply(func, axis=1) for rowwise styles
# + Styler.apply(func, axis=None) for tablewise styles
# + df.style.format("{:.2%}")
# + df.style.format({'B': "{:0<4.0f}", 'D': '{:+.2f}'})

# %% [markdown]
# + Styling export to excel xlsm format 無法使用
# +

# %%
import pandas as pd
import numpy as np
print(pd.__version__)
# Out:
# 0.22.0

# %%
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[0, 2] = np.nan
df
# Out:
#       A         B         C         D         E
# 0   1.0  1.329212       NaN -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011 -0.481165  0.850229
# 4   5.0  1.453425  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538  0.290720

# %%
def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color

# %%
# 傳入 Series
def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

# %%
def highlight_max(data, color='yellow'):
    '''
    highlight the maximum in a Series or DataFrame
    '''
    attr = 'background-color: {}'.format(color)
    if data.ndim == 1:  # Series from .apply(axis=0) or axis=1
        is_max = data == data.max()
        return [attr if v else '' for v in is_max]
    else:  # from .apply(axis=None)
        is_max = data == data.max().max()
        return pd.DataFrame(np.where(is_max, attr, ''),
                            index=data.index, columns=data.columns)

# %%
df.style.applymap(color_negative_red).apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_2da91422_3c8c_11e9_b4e8_1002b5165133row0_col0 {
#             color:  black;
#             : ;
#         }    #T_2da91422_3c8c_11e9_b4e8_1002b5165133row0_col1 {
#             color:  black;
#             : ;
#         }    #T_2da91422_3c8c_11e9_b4e8_1002b5165133row0_col2 {
#             color:  black;
#             : ;
#         }    #T_2da91422_3c8c_11e9_b4e8_1002b5165133row0_col3 {
#             color:  red;
#             : ;
#         }    #T_2da91422_3c8c_11e9_b4e8_1002b5165133row0_col4 {
#             color:  red;
#             : ;
#         }    #T_2da91422_3c8c_11e9_b4e8_1002b5165133row1_col0 {
#             color:  black;
#             : ;
#         }    #T_2da91422_3c8c_11e9_b4e8_1002b5165133row1_col1 {
#             color:  red;
#             : ;
#         }    #T_2da91422_3c8c_11e9_b4e8_1002b5165133row1_col2 {
#             color:  red;
#             : ;
#         }    #T_2da91422_3c8c_11e9_b4e8_1002b5165133row1_col3 {
# ...

# %%
df.style.applymap(color_negative_red,subset=pd.IndexSlice[['B', 'D']])
# Out:
# <style  type="text/css" >
#     #T_2fef2aba_3c8c_11e9_b928_1002b5165133row0_col1 {
#             color:  black;
#         }    #T_2fef2aba_3c8c_11e9_b928_1002b5165133row0_col3 {
#             color:  red;
#         }    #T_2fef2aba_3c8c_11e9_b928_1002b5165133row1_col1 {
#             color:  red;
#         }    #T_2fef2aba_3c8c_11e9_b928_1002b5165133row1_col3 {
#             color:  black;
#         }    #T_2fef2aba_3c8c_11e9_b928_1002b5165133row2_col1 {
#             color:  red;
#         }    #T_2fef2aba_3c8c_11e9_b928_1002b5165133row2_col3 {
#             color:  black;
#         }    #T_2fef2aba_3c8c_11e9_b928_1002b5165133row3_col1 {
#             color:  black;
#         }    #T_2fef2aba_3c8c_11e9_b928_1002b5165133row3_col3 {
#             color:  red;
#         }    #T_2fef2aba_3c8c_11e9_b928_1002b5165133row4_col1 {
#             color:  black;
#         }    #T_2fef2aba_3c8c_11e9_b928_1002b5165133row4_col3 {
#             color:  black;
# ...

# %%
dfst1=df.style.applymap(color_negative_red,subset=pd.IndexSlice[['B', 'D']])
#dfst1.to_excel('Max.xlsx')
#df.style.highlight_null().render().split('\n')[:10]
df.style.highlight_null()
#print(df.style.highlight_null().render())
# Out:
# <style  type="text/css" >
#     #T_cbcf5f42_3c8d_11e9_9baf_1002b5165133row0_col2 {
#             background-color:  red;
#         }</style>
# <table id="T_cbcf5f42_3c8d_11e9_9baf_1002b5165133" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >A</th>
#         <th class="col_heading level0 col1" >B</th>
#         <th class="col_heading level0 col2" >C</th>
#         <th class="col_heading level0 col3" >D</th>
#         <th class="col_heading level0 col4" >E</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_cbcf5f42_3c8d_11e9_9baf_1002b5165133level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_cbcf5f42_3c8d_11e9_9baf_1002b5165133row0_col0" class="data row0 col0" >1</td>
#         <td id="T_cbcf5f42_3c8d_11e9_9baf_1002b5165133row0_col1" class="data row0 col1" >1.32921</td>
#         <td id="T_cbcf5f42_3c8d_11e9_9baf_1002b5165133row0_col2" class="data row0 col2" >nan</td>
# ...

# %%
#df.to_html('Max.html',float_format='{0:.1%}'.format,bold_rows=False)
df.to_html('Max.html',classes=['awesome_table_class'])
#print(df.to_html(float_format='{:%}'.format,bold_rows=False))

# %%
df.style.format('{0:.1%}').applymap(color_negative_red, subset=['D', 'E']).set_properties(**{'font-size': '9pt', 'font-family': 'Calibri'}).bar(subset=['A', 'B'], color='lightblue')
# Out:
# <style  type="text/css" >
#     #T_1d516586_3c8e_11e9_aeae_1002b5165133row0_col0 {
#             font-size:  9pt;
#             font-family:  Calibri;
#             width:  10em;
#              height:  80%;
#         }    #T_1d516586_3c8e_11e9_aeae_1002b5165133row0_col1 {
#             font-size:  9pt;
#             font-family:  Calibri;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 89.2%, transparent 0%);
#         }    #T_1d516586_3c8e_11e9_aeae_1002b5165133row0_col2 {
#             font-size:  9pt;
#             font-family:  Calibri;
#         }    #T_1d516586_3c8e_11e9_aeae_1002b5165133row0_col3 {
#             color:  red;
#             font-size:  9pt;
#             font-family:  Calibri;
#         }    #T_1d516586_3c8e_11e9_aeae_1002b5165133row0_col4 {
#             color:  red;
#             font-size:  9pt;
#             font-family:  Calibri;
# ...

# %%
df.style.format('{0:.1%}').applymap(color_negative_red, subset=['D', 'E']).set_properties(**{'font-size': '9pt', 'font-family': 'Calibri'}).bar(subset=['A', 'B'], color='lightblue').render()
# Out:
# '<style  type="text/css" >\n    #T_64817ba2_3c8e_11e9_bd7b_1002b5165133row0_col0 {\n            font-size:  9pt;\n            font-family:  Calibri;\n            width:  10em;\n             height:  80%;\n        }    #T_64817ba2_3c8e_11e9_bd7b_1002b5165133row0_col1 {\n            font-size:  9pt;\n            font-family:  Calibri;\n            width:  10em;\n             height:  80%;\n            background:  linear-gradient(90deg,lightblue 89.2%, transparent 0%);\n        }    #T_64817ba2_3c8e_11e9_bd7b_1002b5165133row0_col2 {\n            font-size:  9pt;\n            font-family:  Calibri;\n        }    #T_64817ba2_3c8e_11e9_bd7b_1002b5165133row0_col3 {\n            color:  red;\n            font-size:  9pt;\n            font-family:  Calibri;\n        }    #T_64817ba2_3c8e_11e9_bd7b_1002b5165133row0_col4 {\n            color:  red;\n            font-size:  9pt;\n            font-family:  Calibri;\n        }    #T_64817ba2_3c8e_11e9_bd7b_1002b5165133row1_col0 {\n            fon
# ...
