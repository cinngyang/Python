# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/cinngyang/Python/blob/master/OpenCV.ipynb)

# %% [markdown]
# ## Reference
# [Python 與 OpenCV ](https://blog.gtwang.org/programming/opencv-basic-image-read-and-write-tutorial/)<br>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2ccc0d14-4ba7-4ffb-a964-5cbb7e6d64dd" name="files[]" multiple disabled />
#      <output id="result-2ccc0d14-4ba7-4ffb-a964-5cbb7e6d64dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Patrick-Dragon.jpg to Patrick-Dragon.jpg
# ...

# %%
import numpy as np
import cv2

# %%
img = cv2.imread('Patrick-Dragon.jpg')
img.shape
# Out:
# (1477, 1108, 3)

# %%
img[0:1]
# Out:
# array([[[241, 229, 201],
#         [241, 229, 201],
#         [241, 229, 201],
#         ...,
#         [231, 214, 193],
#         [230, 213, 192],
#         [229, 212, 191]]], dtype=uint8)
